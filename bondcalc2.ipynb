# %%
import pandas as pd
import tempfile
from io import StringIO
pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', None)

# %%
def importdf(filename):
    with open(filename, 'r') as fin:
        data = fin.read().splitlines(True)

        data = data[2:]
        data = data[:-2]

        tf = tempfile.NamedTemporaryFile(mode='w')
        tf.writelines(data)
        tf.seek(0)
        df = pd.read_csv(tf.name)
        tf.close()
        return(df)
        #df = pd.read_csv

# %%
df1 = importdf('lindarollover.csv')
df2 = importdf('main.csv')
df3 = importdf('ericira.csv')
print(type(df1))
df = pd.concat([df1, df2, df3])
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        Symbol                                        Description  Quantity  \
# 0   61690DBB3  MORGAN STANLEY BA 5.2%25CD FDIC INS DUE 01/06/...    33,000
# 1   912796ZN2          US TREASURY BILL23U S T BILL DUE 12/28/23    33,000
# 2   912810ET1       US TREASURY 7.625%02/25UST BOND DUE 02/15/25    31,000
# 3   912828D56      US TREASU NT 2.375%08/24UST NOTE DUE 08/15/24    71,000
# 4   912828V23      US TREASUR NT 2.25%12/23UST NOTE DUE 12/31/23    17,000
# ..        ...                                                ...       ...
# 37  91282CGG0      US TREASU NT 4.125%01/25UST NOTE DUE 01/31/25   255,000
# 38  91282CGU9      US TREASU NT 3.875%03/25UST NOTE DUE 03/31/25    75,000
# 39  91282CHD6      US TREASUR NT 4.25%05/25UST NOTE DUE 05/31/25    96,000
# 40  91282CJB8         US TREASUR NT 5%09/25UST NOTE DUE 09/30/25    75,000
# 41      SNOXX                    SCHWAB TREASURY OBLIG MONEY INV  1,127.81
#
#          Price Price Change $ Price Change % Market Value Day Change %  \
# 0     $99.7283       -$0.0004            NaN    $32910.34          NaN
# 1    $99.44003       $0.04421          0.04%    $32815.21        0.04%
# 2   $102.95312      -$0.01562         -0.02%    $31915.47       -0.02%
# 3    $97.85938       $0.01562          0.02%    $69480.16        0.02%
# 4      $99.625       $0.03125          0.03%    $16936.25        0.03%
# ..         ...            ...            ...          ...          ...
# 37      $98.75      -$0.03125         -0.03%    $251812.5       -0.03%
# 38   $98.32812      -$0.03125         -0.03%    $73746.09       -0.03%
# 39   $98.79688       -$0.0625         -0.06%    $94845.00       -0.06%
# 40  $100.09375      -$0.09375         -0.09%    $75070.31       -0.09%
# 41       $1.00            NaN            NaN     $1127.81          NaN
#
#    Day Change $  Cost Basis Gain/Loss % Gain/Loss $   Ratings  \
# 0        -$0.13   $33000.00      -0.27%     -$89.66   NR / NR
# 1        $14.59   $31561.86       3.97%    $1253.35   NR / NR
# 2        -$4.84   $31973.09      -0.18%     -$57.62  NR / Aaa
# 3        $11.09   $69139.89       0.49%     $340.27  NR / Aaa
# 4         $5.31    $16702.5        1.4%     $233.75  NR / Aaa
# ..          ...         ...         ...         ...       ...
# 37      -$79.69  $253105.01      -0.51%   -$1292.51  NR / Aaa
# 38      -$23.44   $73832.68      -0.12%     -$86.59  NR / Aaa
# 39      -$60.00   $95527.32      -0.71%    -$682.32  NR / Aaa
# 40      -$70.31   $74853.55       0.29%     $216.76  NR / Aaa
# 41          NaN    $1127.81          0%       $0.00        --
#
#    Reinvest Dividends? Capital Gains? % Of Account Expiration/Maturity  \
# 0                   No             --       10.52%          01/06/2025
# 1                   No             --       10.49%          12/28/2023
# 2                   No             --        10.2%          02/15/2025
# 3                   No             --       22.21%          08/15/2024
# 4                   No             --        5.41%          12/31/2023
# ..                 ...            ...          ...                 ...
# 37                  No             --       10.17%          01/31/2025
# 38                  No             --        2.98%          03/31/2025
# 39                  No             --        3.83%          05/31/2025
# 40                  No             --        3.03%          09/30/2025
# 41                 Yes            Yes        0.05%                  --
#
#    Dividend Yield Last Dividend Ex-Dividend Date Intrinsic Value  \
# 0              --            --               --              --
# 1              --            --               --              --
# 2              --            --               --              --
# 3              --            --               --              --
# 4              --            --               --              --
# ..            ...           ...              ...             ...
# 37             --            --               --              --
# 38             --            --               --              --
# 39             --            --               --              --
# 40             --            --               --              --
# 41             --            --               --              --
#
#             Security Type
# 0            Fixed Income
# 1            Fixed Income
# 2            Fixed Income
# 3            Fixed Income
# 4            Fixed Income
# ..                    ...
# 37           Fixed Income
# 38           Fixed Income
# 39           Fixed Income
# 40           Fixed Income
# 41  Cash and Money Market
#
# [90 rows x 22 columns]

# %%
df=df[df["Expiration/Maturity"]!="--"]
df
# Out:
#        Symbol                                        Description Quantity  \
# 0   61690DBB3  MORGAN STANLEY BA 5.2%25CD FDIC INS DUE 01/06/...   33,000
# 1   912796ZN2          US TREASURY BILL23U S T BILL DUE 12/28/23   33,000
# 2   912810ET1       US TREASURY 7.625%02/25UST BOND DUE 02/15/25   31,000
# 3   912828D56      US TREASU NT 2.375%08/24UST NOTE DUE 08/15/24   71,000
# 4   912828V23      US TREASUR NT 2.25%12/23UST NOTE DUE 12/31/23   17,000
# ..        ...                                                ...      ...
# 36  91282CGD7      US TREASUR NT 4.25%12/24UST NOTE DUE 12/31/24   75,000
# 37  91282CGG0      US TREASU NT 4.125%01/25UST NOTE DUE 01/31/25  255,000
# 38  91282CGU9      US TREASU NT 3.875%03/25UST NOTE DUE 03/31/25   75,000
# 39  91282CHD6      US TREASUR NT 4.25%05/25UST NOTE DUE 05/31/25   96,000
# 40  91282CJB8         US TREASUR NT 5%09/25UST NOTE DUE 09/30/25   75,000
#
#          Price Price Change $ Price Change % Market Value Day Change %  \
# 0     $99.7283       -$0.0004            NaN    $32910.34          NaN
# 1    $99.44003       $0.04421          0.04%    $32815.21        0.04%
# 2   $102.95312      -$0.01562         -0.02%    $31915.47       -0.02%
# 3    $97.85938       $0.01562          0.02%    $69480.16        0.02%
# 4      $99.625       $0.03125          0.03%    $16936.25        0.03%
# ..         ...            ...            ...          ...          ...
# 36   $98.92188      -$0.01562         -0.02%    $74191.41       -0.02%
# 37      $98.75      -$0.03125         -0.03%    $251812.5       -0.03%
# 38   $98.32812      -$0.03125         -0.03%    $73746.09       -0.03%
# 39   $98.79688       -$0.0625         -0.06%    $94845.00       -0.06%
# 40  $100.09375      -$0.09375         -0.09%    $75070.31       -0.09%
#
#    Day Change $  Cost Basis Gain/Loss % Gain/Loss $   Ratings  \
# 0        -$0.13   $33000.00      -0.27%     -$89.66   NR / NR
# 1        $14.59   $31561.86       3.97%    $1253.35   NR / NR
# 2        -$4.84   $31973.09      -0.18%     -$57.62  NR / Aaa
# 3        $11.09   $69139.89       0.49%     $340.27  NR / Aaa
# 4         $5.31    $16702.5        1.4%     $233.75  NR / Aaa
# ..          ...         ...         ...         ...       ...
# 36      -$11.72   $74207.81      -0.02%      -$16.4  NR / Aaa
# 37      -$79.69  $253105.01      -0.51%   -$1292.51  NR / Aaa
# 38      -$23.44   $73832.68      -0.12%     -$86.59  NR / Aaa
# 39      -$60.00   $95527.32      -0.71%    -$682.32  NR / Aaa
# 40      -$70.31   $74853.55       0.29%     $216.76  NR / Aaa
#
#    Reinvest Dividends? Capital Gains? % Of Account Expiration/Maturity  \
# 0                   No             --       10.52%          01/06/2025
# 1                   No             --       10.49%          12/28/2023
# 2                   No             --        10.2%          02/15/2025
# 3                   No             --       22.21%          08/15/2024
# 4                   No             --        5.41%          12/31/2023
# ..                 ...            ...          ...                 ...
# 36                  No             --           3%          12/31/2024
# 37                  No             --       10.17%          01/31/2025
# 38                  No             --        2.98%          03/31/2025
# 39                  No             --        3.83%          05/31/2025
# 40                  No             --        3.03%          09/30/2025
#
#    Dividend Yield Last Dividend Ex-Dividend Date Intrinsic Value Security Type
# 0              --            --               --              --  Fixed Income
# 1              --            --               --              --  Fixed Income
# 2              --            --               --              --  Fixed Income
# 3              --            --               --              --  Fixed Income
# 4              --            --               --              --  Fixed Income
# ..            ...           ...              ...             ...           ...
# 36             --            --               --              --  Fixed Income
# 37             --            --               --              --  Fixed Income
# 38             --            --               --              --  Fixed Income
# 39             --            --               --              --  Fixed Income
# 40             --            --               --              --  Fixed Income
#
# [73 rows x 22 columns]

# %%
from datetime import datetime

df.loc[:,("maturity")] = pd.to_datetime(df["Expiration/Maturity"])
df.loc[:,("Quantity")] = df["Quantity"].str.replace(',','')
df=df[["maturity","Quantity"]]

df
# Out:
#      maturity Quantity
# 0  2025-01-06    33000
# 1  2023-12-28    33000
# 2  2025-02-15    31000
# 3  2024-08-15    71000
# 4  2023-12-31    17000
# ..        ...      ...
# 36 2024-12-31    75000
# 37 2025-01-31   255000
# 38 2025-03-31    75000
# 39 2025-05-31    96000
# 40 2025-09-30    75000
#
# [73 rows x 2 columns]

# %%
#df=df.set_index(['maturity'])
#print(df5['maturity'].min())
#print(df5['maturity'].max())

#print(df5.index)
#print(d.index)
#d2 = d.asfreq(freq='90D',fill_value=42)
#display(d)
#display(d2)

idx = pd.date_range(df["maturity"].min(),df["maturity"].max(),freq='90D')
df = df.set_index(["maturity"])

#display(idx)
#df = df.reindex(idx)
#df = df.asfreq('d',fill_value=0)
#display(d3)
#df6['id'] = range(1,1+len(df6))
#df6.insert(0,'id',range(1,1 + len(df6)))
#df6=df6.set_index('id')
##display(df6)
#df.reset_index(inplace=True)
#df.set_index('maturity', drop=False)
display(df)
# Out:
#            Quantity
# maturity
# 2025-01-06    33000
# 2023-12-28    33000
# 2025-02-15    31000
# 2024-08-15    71000
# 2023-12-31    17000
# ...             ...
# 2024-12-31    75000
# 2025-01-31   255000
# 2025-03-31    75000
# 2025-05-31    96000
# 2025-09-30    75000
#
# [73 rows x 1 columns]

# %%
display(df.index)
# Out:
# DatetimeIndex(['2025-01-06', '2023-12-28', '2025-02-15', '2024-08-15',
#                '2023-12-31', '2024-03-31', '2024-04-15', '2024-12-15',
#                '2024-06-30', '2025-08-31', '2025-02-18', '2026-06-15',
#                '2026-12-21', '2025-08-18', '2024-12-16', '2024-06-13',
#                '2025-08-11', '2026-08-10', '2025-06-16', '2023-11-30',
#                '2024-05-16', '2024-02-01', '2024-08-08', '2024-02-08',
#                '2024-05-02', '2025-08-15', '2026-03-31', '2027-03-31',
#                '2024-03-31', '2024-07-31', '2025-12-15', '2024-12-31',
#                '2025-01-31', '2026-02-15', '2025-02-28', '2028-03-31',
#                '2025-03-31', '2025-06-30', '2029-01-23', '2041-03-01',
#                '2027-11-02', '2025-07-18', '2033-03-15', '2026-02-08',
#                '2026-02-09', '2027-02-09', '2026-02-23', '2024-01-11',
#                '2026-08-10', '2026-08-18', '2025-08-11', '2027-08-09',
#                '2027-11-22', '2023-11-21', '2024-04-18', '2024-01-11',
#                '2024-02-01', '2024-02-08', '2024-01-31', '2024-03-31',
#                '2024-07-31', '2025-01-31', '2025-07-31', '2024-08-15',
#                '2024-12-15', '2024-06-30', '2024-07-31', '2024-09-30',
#                '2024-12-31', '2025-01-31', '2025-03-31', '2025-05-31',
#                '2025-09-30'],
#               dtype='datetime64[ns]', name='maturity', freq=None)

# %%
df.loc[:,("maturityq")] = pd.PeriodIndex(df.index, freq='Q')
df=df.sort_values(by=["maturity"],ascending=True)
##display(df)
df.loc[:,("Quantityi")] = df["Quantity"].astype(int)
df = df[["maturityq","Quantityi"]]
df
results = df.groupby(by=['maturityq']).sum()
display(results)
# Out:
#            Quantityi
# maturityq
# 2023Q4         80000
# 2024Q1        651000
# 2024Q2        426000
# 2024Q3        641000
# 2024Q4        186000
# 2025Q1        695000
# 2025Q2        141000
# 2025Q3        346000
# 2025Q4         24000
# 2026Q1        158000
# 2026Q2         24000
# 2026Q3        104000
# 2026Q4         24000
# 2027Q1         85000
# 2027Q3         35000
# 2027Q4         33000
# 2028Q1         50000
# 2029Q1          5000
# 2033Q1          4000
# 2041Q1          3000

# %%
d = df5.set_index('maturity')
#display(d)
idx = pd.date_range(d.index.min(),d.index.max(),freq='90D')
#display(idx)
#display(idx)
#display(pd.PeriodIndex(idx, freq='Q'))
#d.index = pd.to_datetime(d.index, format='%Y-%m-%d')
#print(idx.size)
#print(type(idx))
#print(pd.PeriodIndex(df4["maturity"], freq='Q'))
#pidx = pd.PeriodIndex(df4["maturity"], freq='Q')
print('miss:',idx.difference(d.index))
#print('pmiss:',pidx.difference(d.index))
d2=d.reindex(idx,method='bfill')
#display(d)
#display(d2)

# %%
maxrows = pd.get_option('display.max_rows')

#print(df6.index)
#print(df6.columns)

#display(df6)
df6.loc[:,("maturityq")] = pd.PeriodIndex(df6["maturity"], freq='Q')
#display(df6)
d  = df6.set_index('maturityq')
##print(d.index)
#display(d)
d=d[["Quantityi"]]
#display(d)

results = d.groupby(by=['maturityq']).sum()
pd.set_option('display.max_rows', 999)
display(results)
pd.set_option('display.max_rows', maxrows)

# %%
with open('lindarollover.csv', 'r') as fin:
    data = fin.read().splitlines(True)

data = data[2:]
data = data[:-2]
with open('lindarollover2.csv', 'w') as fout:
    fout.writelines(data)

# %%
df = pd.read_csv('lindarollover2.csv')
#df["Expiration/Maturity"]
df2=df[["Symbol","Description","Quantity","Expiration/Maturity"]]
df2

df3=df2.sort_values(by=["Expiration/Maturity"],ascending=False)
df3

# %%
df6 = (df5.set_index('maturity')
       .reindex(pd.date_range(start='12/31/2022', end='12/31/2033', freq='QS'))
       .rename_axis(['maturity'])
       .fillna(0)
       .reset_index())

#df6
